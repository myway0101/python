# %% [markdown]
# ## Python 기초 문법

# %%
print("Hello World")
# Out:
# Hello World

# %%
"Hello World"
# Out:
# 'Hello World'

# %%
"Hello"
"World"
# Out:
# 'World'

# %% [markdown]
# ### 주석(Comment)
#
# * 주석은 `#`으로 표현한다.
# * 컨트롤+ / 로 여러줄 주석 가능

# %%
# 이 줄은 주석입니다. 실행되지 않습니다.
print("Hello")
# Out:
# Hello

# %%
print(1+2) # 1+2 계산

# %%
# 여러줄 주석은 ctrl + /
# print("Hello")
# print(1+2)
# print(2/4)

# %% [markdown]
# # 변수(variable) 및 자료형

# %% [markdown]
# * 변수는 변할 수 있는 값을 저장하는 공간
#
# * 변수는 `=`을 통해 할당(assignment) 된다.
#
# * 해당 자료형을 확인하기 위해서는 `type()`을 활용한다.

# %%
 x = 1
 print(x)
# Out:
# 1

# %%
x = 2
print(x)
# Out:
# 2

# %%
x = 1
y = 2
print(x)
print(y)
# Out:
# 1
# 2

# %%
x = 1
y = 2
print("x =", x)
print("y =", y)
# Out:
# x = 1
# y = 2

# %%
print(type(x))
# Out:
# <class 'int'>

# %%
z = "파이썬"
print(type(z))
# Out:
# <class 'str'>

# %%
x = "1"
print(x)
# Out:
# 1

# %% [markdown]
# * 같은 값을 동시에 할당할 수 있다.

# %%
x = y = 1
print(x, y)
# Out:
# 1 1

# %% [markdown]
# * 다른 값을 동시에 할당 가능하다.

# %%
x, y = 1, 2
print(x, y)
# Out:
# 1 2

# %% [markdown]
# ## 수치형(Numbers)
#
# ###  `int` (정수)
#
# 모든 정수는 `int`로 표현된다.

# %%
a = 3
print(a)
print(type(a))
# Out:
# 3
# <class 'int'>

# %% [markdown]
# ### `float`(부동소수점, 실수)
#
# 실수는 `float`로 표현된다.

# %%
a = 3.5
print(a)
print(type(a))
# Out:
# 3.5
# <class 'float'>

# %%
print(a)
# Out:
# 3.5

# %% [markdown]
# ## 실습
# 변수 a에 10을 할당하고, 변수 b에 5.0을 할당하고, 변수 c에 a+b를 수행하여 c를 출력하세요. 변수 c의 type 또한 출력하세요.

# %%
a = 10
b = 5.0
c = a+b
print(c)
print(type(c))
# Out:
# 15.0
# <class 'float'>

# %% [markdown]
# ## Bool
#
# 파이썬에는 `True`와 `False`로 이뤄진 `bool` 타입이 있다.
#
# 비교/논리 연산을 수행 등에서 활용된다.

# %%
print(type(True))
# Out:
# <class 'bool'>

# %%
print(type(False))
# Out:
# <class 'bool'>

# %%
a = 1
print(a == 1)
print(a == 0)
# Out:
# True
# False

# %% [markdown]
# # 연산자
#
# ## 산술 연산자
# Python에서는 기본적인 사칙연산이 가능합니다.
#
# |연산자|내용|
# |----|---|
# |+|덧셈|
# |-|뺄셈|
# |\*|곱셈|
# |/|나눗셈|
# |//|몫|
# |%|나머지(modulo)|
# |\*\*|거듭제곱|

# %%
print(5/2)
# Out:
# 2.5

# %%
print(5//2)
# Out:
# 2

# %%
print(5%2)
# Out:
# 1

# %%
q, r = divmod(5, 2)
print(q, r)
# Out:
# 2 1

# %%
print(2**2)
print(2**10)
# Out:
# 4
# 1024

# %% [markdown]
# * 양수/음수도 표현 가능합니다.

# %%
num = -4
print(num)
print(num+4)
# Out:
# -4
# 0

# %% [markdown]
# ## 실습
# 97개의 빵(bread)을 3개씩(count) 같은 반의 친구들에게 나누어 주려고 합니다. 최대 몇명(max_count)에게 나누어 줄 수 있는지 구하고, 남는 빵(rest)의 개수도 구해봅시다.

# %%
bread = 97
count = 3
max_count = ##코드입력##
rest =  ##코드입력##
print("빵을 나누어 줄 수 있는 최대 학생수: ", max_count)
print("남는 빵의 개수: ", rest)
# Out:
# 빵을 나누어 줄 수 있는 최대 학생수:  32
# 남는 빵의 개수:  1

# %%
97/3
# Out:
# 32.333333333333336

# %% [markdown]
# ## 비교 연산자
#
# 우리가 수학에서 배운 연산자와 동일하게 값을 비교할 수 있습니다.
#
# |연산자|내용|
# |----|---|
# |a > b|초과|
# |a < b|미만|
# |a >= b|이상|
# |a <= b|이하|
# |a == b|같음|
# |a != b|같지않음|

# %%
a = 1
b = 2
print(a>b)
print(a<=b)
print(a!=b)
# Out:
# False
# True
# True

# %% [markdown]
# ## 논리 연산자
#
# |연산자|내용|
# |---|---|
# |a and b|a와 b 모두 True시만 True|
# |a or b|a 와 b 모두 False시만 False|
# |not a|True -> False, False -> True|
#
# 우리가 보통 알고 있는 `&` `|`은 파이썬에서 비트 연산자이다.

# %%
print( True and True)
print( True or False)
print( True and False)
print(not False)
# Out:
# True
# True
# False
# True

# %% [markdown]
# ## 복합 연산자
#
# 복합 연산자는 연산과 대입이 함께 이뤄진다.
#
# 가장 많이 활용되는 경우는 반복문을 통해서 갯수를 카운트하거나 할 때 활용된다.
#
# |연산자|내용|
# |----|---|
# |a += b|a = a + b|
# |a -= b|a = a - b|
# |a \*= b|a = a \* b|
# |a /= b|a = a / b|
# |a //= b|a = a // b|
# |a %= b|a = a % b|
# |a \*\*= b|a = a ** b|

# %%
a = 1
a += 1 # a = a+1
print(a)
# Out:
# 2

# %% [markdown]
# ## 연산자 우선순위
#
# 0. `()`을 통한 grouping
#
# 1. Slicing
#
# 2. Indexing
#
# 3. 제곱연산자
#     \*\*
#
# 4. 단항연산자
#     +, - (음수/양수 부호)
#
# 5. 산술연산자
#     \*, /, %
#
# 6. 산술연산자
#     +, -
#
# 7. 비교연산자, `in`, `is`
#
# 8. `not`
#
# 9. `and`
#
# 10. `or`

# %%
(3+(4*4)) > ((5*4)+3-1)
# Out:
# False

# %% [markdown]
# # 기초 형변환(Type conversion, Typecasting)
#
#
# 파이썬에서 데이터타입은 서로 변환할 수 있다.

# %% [markdown]
# ## 명시적 형변환(Explicit Type Conversion)
#
# 위의 상황을 제외하고는 모두 명시적으로 형 변환을 해주어야한다.
#
# * string -> intger  : 형식에 맞는 숫자만 가능
# * integer -> string : 모두 가능
#
# 암시적 형변환이 되는 모든 경우도 명시적으로 형변환이 가능하다.
#
# * `int()` : string, float를 int로 변환
# * `float()` : string, int를 float로 변환
# * `str()` : int, float, list, tuple, dictionary를 문자열로 변환
#
# `list(), tuple()` 등은 다음 챕터에서 배울 예정이다.

# %%
a = 1
print(type(a))
b = str(a)
print(type(b))
# Out:
# <class 'int'>
# <class 'str'>

# %%
a = 3.5
print(type(a))
b = int(a)
print(b)
print(type(b))
# Out:
# <class 'float'>
# 3
# <class 'int'>

# %%
a = 3
b = float(a)
print(b)
# Out:
# 3.0

# %%
a = 5
b = str(a)
print(type(b))
# Out:
# <class 'str'>

# %%
a = 5.5
b = str(a)
print(type(b))
print(b)
c = float(b)
print(type(c))
# Out:
# <class 'str'>
# 5.5
# <class 'float'>

# %%
a = "5.5"
b = float(a)
print(b)
c = int(b)
print(c)
# Out:
# 5.5
# 5
