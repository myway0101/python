# %% [markdown]
# # 모듈 사용하기

# %% [markdown]
# ## 개요
#
# * 모듈이란 함수나 변수 또는 클래스를 모아 놓은 파일(xxx.py)이다.
# * 다른 사람들이 이미 만들어 놓은 모듈을 사용할 수도 있고 우리가 직접 만들어서 사용할 수도 있다.

# %% [markdown]
# * import를 이용해 이미 만들어 놓은 파이썬 모듈을 사용할 수 있다.
# * import 모듈이름
#  * 모듈 전체 불러오기
#  * 사용시에는 모듈이름.함수이름 (일반적으로 모듈안에는 여러개의 함수가 들어있음)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# * from 모듈이름 import 함수이름
#  * 모듈내에서 필요한 것만 가져오기
#  * 사용시에는 바로 함수이름
# * from 모듈이름 import *

# %% [markdown]
# * ※ import는 현재 디렉터리에 있는 파일이나 파이썬 라이브러리가 저장된 디렉터리에 있는 모듈만 불러올 수 있다.
# * 파이썬 라이브러리는 파이썬을 설치할 때 자동으로 설치되는 파이썬 모듈을 말한다.

# %% [markdown]
# ### 모듈 사용의 장점
# * 프로그램 개발 시간을 단축시킬 수 있음
# * 모듈은 이미 검증된 코드이므로 오류가 적음
# * 팀원들이 기능 구현을 분업화하고 공유할 수 있어 전체적인 작업 속도를 향상시킬 수 있음

# %% [markdown]
# **파이썬라이브러리 모듈사용**

# %%
# 수학관련 라이브러리
import math

# %%
print(math.log(8, 2))
# Out:
# 3.0

# %%
math?
math.cos?

# %%
print(math.sqrt(4))
# Out:
# 2.0

# %%
from math import sqrt
print(sqrt(4))
# Out:
# 2.0

# %%
from math import*
print(cos(10))
# Out:
# -0.8390715290764524

# %%
# random은 난수(규칙이 없는 임의의 수)를 발생시키는 모듈

# %%
import random

# %%
print(random.random())
# Out:
# 0.8579559111148535

# %%
print(random.randint(1, 10))
# Out:
# 8

# %%
from random import*
print(randint(1, 10))
# Out:
# 8

# %% [markdown]
# ### 실습문제 - random 활용
#
#
# > **랜덤한 숫자 맞추기 프로그램.
# 1부터 10사이의 랜덤한 값을 사용자가 숫자를 여러번 입력하여 맞추는 프로그램 작성
# while 반복문과 조건문, break를 사용**
#
# ---
#
# ```
# 예시 출력)
# 숫자를 입력하여 맞혀 보세요?   5
# 너무 작아요.
#
# 숫자를 입력하여 맞혀 보세요?   10
# 너무 커요.
#
# 숫자를 입력하여 맞혀 보세요?   7
# 정답
#
# ```

# %%
##코드입력##
n = random.randint(1, 10)
print(n)
while True:     
    x = int(input("숫자를 입력하여 맞혀 보세요? "))     
    ###################
    ##   코드입력    ## 
  
    
    
    ###################
# Out:
# 7
# 숫자를 입력하여 맞혀 보세요? 6
# 입력 값이 작아요
# 숫자를 입력하여 맞혀 보세요? 8
# 입력 값이 커요
# 숫자를 입력하여 맞혀 보세요? 7
# 정답

# %% [markdown]
# **모듈 설치후 사용**

# %%
# !pip install icecream
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import icecream

# %%
#디버깅하기 좋은 모듈
from icecream import ic

# %%
a = 10
b = "10"
print(a)
print(b)
ic(a)
ic(b)
# Out:
# ic| a: 10
# ic| b: '10'
# 10
# 10
# '10'
